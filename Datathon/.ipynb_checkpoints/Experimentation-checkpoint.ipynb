# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lc_accepted=pd.read_csv('lc_accepted_short.csv')
lc_rejected=pd.read_csv('lc_rejected_short.csv')
# Out:
# /var/folders/d3/ry6v0r7j28d4wdqwrz_hvdqc0000gn/T/ipykernel_42100/1575947156.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   lc_accepted=pd.read_csv('lc_accepted_short.csv')

# %%
lc_accepted.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# 3     14.85       829.90     C        C5  ...                            NaN
# 4     22.45       289.91     F        F1  ...                            NaN
#
# ...

# %%
lc_accepted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 151 entries, id to settlement_term
# dtypes: float64(114), int64(1), object(36)
# memory usage: 57.6+ MB

# %%
pd.set_option('display.max_rows', None)  # or 1000
print(lc_accepted.isnull().sum())
# Out:
# id                                                0
# member_id                                     50000
# loan_amnt                                         0
# funded_amnt                                       0
# funded_amnt_inv                                   0
# term                                              0
# int_rate                                          0
# installment                                       0
# grade                                             0
# sub_grade                                         0
# emp_title                                      2995
# emp_length                                     2989
# home_ownership                                    0
# annual_inc                                        0
# verification_status                               0
# issue_d                                           0
# loan_status                                       0
# pymnt_plan                                        0
# ...
